# %%
from bs4 import BeautifulSoup # Import BeautifulSoup for parsing HTML content
import pandas as pd           # Import pandas to store data in DataFrame and export to Excel or Csv etc. 
import requests               # Import requests to send HTTP requests to the website

# %%
url = requests.get('https://www.greateasternretail.com/shop/televisions/led/') # Send GET request to the TV listing page

# %%
soup = BeautifulSoup(url.content, 'html.parser') # Parse the HTML content using BeautifulSoup

# %%
all_tvs = soup.find_all(class_='product-item') # Find all TV product blocks on the page
len(all_tvs)
# Out:
# 58

# %%
items = all_tvs[0]   # Access the first TV item (for testing and understanding structure)

# %%
model = items.find(class_='text-blue font-weight-bold').text     # Extract TV model name
model
# Out:
# 'INNOTRICS 32IN PRO II - 32" LED'

# %%
price = items.find(class_='font-size-20 text-blue-2 text-decoration-none').text.strip('\n ')   # Extract our selling price
price
# Out:
# '₹7490'

# %%
offer = items.find(class_='dis-per-sm ml-2').text.strip().replace(' ','').replace('\n',' ')     # Extract discount offer percentage
offer
# Out:
# '62% off'

# %%
actual_price = items.find(class_='font-size-12 mb-0 position-absolute bottom--100').text.strip().replace('\n','').replace(' ','').replace('MRP','')   # Extract actual MRP price and clean unwanted text
actual_price
# Out:
# '₹20000'

# %%
all_items = []  # Create empty list to store all TV data

for item in all_tvs:       # Loop through each TV product
    model = item.find(class_='text-blue font-weight-bold')                              # Find model name element
    price = item.find(class_='font-size-20 text-blue-2 text-decoration-none')           # Find our price element
    offer = item.find(class_='dis-per-sm ml-2')                                         # Find discount offer element
    actual_price = item.find(class_='font-size-12 mb-0 position-absolute bottom--100')  # Find actual MRP price element

    d1 = {                                                                              # Store extracted data in dictionary
        'MODEL': model.text.strip() if model else None,
        'OUR PRICE': price.text.strip() if price else None,
        'OFFER': offer.text.strip().replace('\n', '').replace(' ', '') if offer else None,
        'ACTUAL PRICE': actual_price.text
                            .replace('MRP', '')
                            .strip()
                            .replace('\n', '')
                            .replace(' ', '') if actual_price else None
    }

    all_items.append(d1)                                                                # Append dictionary to list

# %%
df = pd.DataFrame(all_items)     # Convert list of dictionaries into pandas DataFrame
df = df.dropna(how='all')        # Remove rows where all values are missing
df
# Out:
#                                                 MODEL OUR PRICE   OFFER  \
# 0                     INNOTRICS 32IN PRO II - 32" LED     ₹7490  62%off
# 1                  INNOTRICS 32IN SMART PRO - 32" LED    ₹10991  56%off
# 2   OnePlus Y Series 80 cm (32 inch) HD Ready LED ...    ₹15900  20%off
# 3   LG 80cm (32 Inch) HD Ready LED Smart TV (32LM5...    ₹16800  25%off
# 4   LG 81.28 cm (32 inch) Full HD LED Smart TV  (3...    ₹17400  18%off
# 5   Haier 80 cm (32 inch) HD Ready LED TV (LE32W2000)    ₹17500  37%off
# 6   TCL P715 108 cm (43 inch) Ultra HD (4K) LED Sm...    ₹22990  61%off
# 7   Haier 109 cm (43 inches) UHD Smart Android LED...    ₹26352  48%off
# 8   Lloyd 109 cm (43 Inches) Full HD Smart LED TV ...    ₹26900  37%off
# 9   METZ (43 Inch) 4K Smart  Android TV  SKYWORTH ...    ₹28000  29%off
# 10  Samsung 108 cm (43 inches) Full HD LED Smart T...    ₹28490  32%off
# 11  SAMSUNG 108 cm (43 inch) Ultra HD (4K) LED Sma...    ₹28582  40%off
# 12        LG 43LM5760PTC 43 inch Full HD Smart LED TV    ₹30921  29%off
# 13    LG 43UP7740PTZ 43 Inch 109.22cm 4K Smart UHD TV    ₹30999  48%off
# 14  Sony Bravia 108 cm (43 inches) Full HD Smart L...    ₹36971  31%off
# 15     Lloyd 55 Inches 4K UHD Smart LED TV (55US850C)    ₹38000  57%off
# 16        LG 43NANO75TPZ 43 inch 4K (Ultra HD) LED TV    ₹38003  49%off
# 17  SAMSUNG 139 cm (55 inch) Ultra HD (4K) LED Sma...    ₹40869  42%off
# 18  LG 139 cm (55 inch) Ultra HD (4K) LED Smart TV...    ₹41499  42%off
# 19  SONY X70L 108 cm (43 inch) Ultra HD (4K) LED S...    ₹42290  29%off
# 20  SONY X75L 108 cm (43 inch) Ultra HD (4K) LED S...    ₹44990  35%off
# 21  Samsung CU8000 43 inch Ultra HD 4K Smart LED T...    ₹45490  17%off
# 22  Samsung 55 inch (138 cm) Crystal Ultra HD (4K)...    ₹46284  41%off
# 23  Lloyd 146cm (58 Inches) Ultra HD Android Smart...    ₹47990  52%off
# 24  LG 139.7 cm (55 Inches) 4K Ultra HD Smart LED ...    ₹47996  46%off
# 25  SONY X70L 125.7 cm (50 inch) Ultra HD (4K) LED...    ₹52190  30%off
# 26  Sony Bravia 125 cm (50 inches) Full HD LED Sma...    ₹54171  27%off
# 27  LG 139 cm (55 inches) 4K Ultra HD Smart NaNoCe...    ₹82492  48%off
# 28  Sony Bravia X85J Series 139cm (55 Inch) Ultra ...    ₹90240  35%off
#
#    ACTUAL PRICE
# 0        ₹20000
# 1        ₹25000
# 2        ₹19999
# 3        ₹22490
# 4        ₹21240
# 5        ₹27990
# 6        ₹59990
# 7        ₹50990
# 8        ₹42990
# 9        ₹39990
# 10       ₹42400
# 11       ₹47900
# 12       ₹43990
# 13       ₹59990
# 14       ₹53900
# 15       ₹89990
# 16       ₹74990
# 17       ₹70900
# 18       ₹71990
# 19       ₹59900
# 20       ₹69900
# 21       ₹54900
# 22       ₹79400
# 23       ₹99990
# 24       ₹89990
# 25       ₹74900
# 26       ₹74900
# 27      ₹159990
# 28      ₹139900

# %%
df.to_csv('tv_data.csv',index=False)      # Export scraped data to Excel file
